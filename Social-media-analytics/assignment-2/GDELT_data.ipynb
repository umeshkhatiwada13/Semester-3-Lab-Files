# %%
import requests
import pandas as pd
import time

def fetch_gdelt_context(query, max_records=200, start=0):
    base_url = "https://api.gdeltproject.org/api/v2/context/context"
    
    params = {
        'query': query,
        'mode': 'artlist',
        'format': 'json',
        'maxrecords': max_records,
        'start': start
    }
    
    try:
        response = requests.get(base_url, params=params)
        response.raise_for_status()  # Raise an exception for HTTP errors

        # Parse JSON response
        data = response.json()
        articles = data.get('articles', [])

        return articles

    except requests.exceptions.RequestException as e:
        print(f"Error fetching articles: {e}")
        return []

# List of topics to query
topics = [
    'canada'
]

# number of articles to fetch
article_count = 100000

# Initialize DataFrame to store all articles
all_articles_df = pd.DataFrame()

# Fetch data for each topic
for topic in topics:
    start = 0
    while True:
        articles = fetch_gdelt_context(query=topic, max_records=200, start=start)
        if not articles:
            break  # Exit loop if no more articles are returned

        # Convert list of dictionaries to DataFrame
        articles_df = pd.DataFrame(articles)

        # Append to the main DataFrame
        all_articles_df = pd.concat([all_articles_df, articles_df], ignore_index=True)

        # Break if we reach the required number of articles
        if len(all_articles_df) >= article_count:
            break

        # Update start for next page
        start += 200

        print("Fetched total data : ",len(all_articles_df))

        # Pause to respect API rate limits
        time.sleep(1)

    # Check if we have reached the required number of articles
    if len(all_articles_df) >= article_count:
        break

print(f"Fetched {len(all_articles_df)} articles.")

# Save DataFrame to CSV file
all_articles_df.to_csv('data/gdelt_news_articles.csv', index=False)

# Optionally, display or further process the DataFrame
print(all_articles_df.head())
# Out:
# Fetched total data :  97
# Fetched total data :  194
# Fetched total data :  291
# Fetched total data :  388
# Fetched total data :  485
# Fetched total data :  582
# Fetched total data :  679
# Fetched total data :  776
# Fetched total data :  873
# Fetched total data :  970
# Fetched total data :  1067
# Fetched total data :  1164
# Fetched total data :  1261
# Fetched total data :  1358
# Fetched total data :  1455
# Fetched total data :  1552
# Fetched total data :  1649
# Fetched total data :  1746
# Fetched total data :  1843
# Fetched total data :  1940
# Fetched total data :  2037
# Fetched total data :  2134
# Fetched total data :  2231
# Fetched total data :  2328
# Fetched total data :  2425
# Fetched total data :  2522
# Fetched total data :  2619
# Fetched total data :  2716
# Fetched total data :  2813
# Fetched total data :  2910
# Fetched total data :  3007
# Fetched total data :  3104
# Fetched total data :  3201
# Fetched total data :  3298
# Fetched total data :  3395
# Fetched total data :  3492
# Fetched total data :  3589
# Fetched total data :  3686
# Fetched total data :  3783
# Fetched total data :  3880
# Fetched total data :  3977
# Fetched total data :  4074
# Fetched total data :  4171
# Fetched total data :  4268
# Fetched total data :  4365
# Fetched total data :  4462
# Fetched total data :  4559
# Fetched total data :  4656
# Fetched total data :  4753
# Fetched total data :  4850
# Fetched total data :  4947
# Fetched total data :  5044
# Fetched total data :  5141
# Fetched total data :  5238
# Fetched total data :  5335
# Fetched total data :  5432
# Fetched total data :  5529
# Fetched total data :  5626
# Fetched total data :  5723
# Fetched total data :  5820
# Fetched total data :  5917
# Fetched total data :  6014
# Fetched total data :  6111
# Fetched total data :  6208
# Fetched total data :  6305
# Fetched total data :  6402
# Fetched total data :  6499
# Fetched total data :  6596
# Fetched total data :  6693
# Fetched total data :  6790
# Fetched total data :  6887
# Fetched total data :  6984
# Fetched total data :  7081
# Fetched total data :  7178
# Fetched total data :  7275
# Fetched total data :  7372
# Fetched total data :  7469
# Fetched total data :  7566
# Fetched total data :  7663
# Fetched total data :  7760
# Fetched total data :  7857
# Fetched total data :  7954
# Fetched total data :  8051
# Fetched total data :  8148
# Fetched total data :  8245
# Fetched total data :  8342
# Fetched total data :  8439
# Fetched total data :  8536
# Fetched total data :  8633
# Fetched total data :  8730
# Fetched total data :  8827
# Fetched total data :  8924
# Fetched total data :  9021
# Fetched total data :  9118
# Fetched total data :  9215
# Fetched total data :  9312
# Fetched total data :  9409
# Fetched total data :  9506
# Fetched total data :  9603
# Fetched total data :  9700
# Fetched total data :  9797
# Fetched total data :  9894
# Fetched total data :  9991
# Fetched total data :  10088
# Fetched total data :  10185
# Fetched total data :  10282
# Fetched total data :  10379
# Fetched total data :  10476
# Fetched total data :  10573
# Fetched total data :  10670
# Fetched total data :  10767
# Fetched total data :  10864
# Fetched total data :  10961
# Fetched total data :  11058
# Fetched total data :  11155
# Fetched total data :  11252
# Fetched total data :  11349
# Fetched total data :  11446
# Fetched total data :  11543
# Fetched total data :  11640
# Fetched total data :  11737
# Fetched total data :  11834
# Fetched total data :  11931
# Fetched total data :  12028
# Fetched total data :  12125
# Fetched total data :  12222
# Fetched total data :  12319
# Fetched total data :  12416
# Fetched total data :  12513
# Fetched total data :  12610
# Fetched total data :  12707
# Fetched total data :  12804
# Fetched total data :  12901
# Fetched total data :  12998
# Fetched total data :  13095
# Fetched total data :  13192
# Fetched total data :  13289
# Fetched total data :  13386
# Fetched total data :  13483
# Fetched total data :  13580
# Fetched total data :  13677
# Fetched total data :  13774
# Fetched total data :  13871
# Fetched total data :  13968
# Fetched total data :  14065
# Fetched total data :  14162
# Fetched total data :  14259
# Fetched total data :  14356
# Fetched total data :  14453
# Fetched total data :  14550
# Fetched total data :  14647
# Fetched total data :  14744
# Fetched total data :  14841
# Fetched total data :  14938
# Fetched total data :  15035
# Fetched total data :  15132
# Fetched total data :  15229
# Fetched total data :  15326
# Fetched total data :  15423
# Fetched total data :  15520
# Fetched total data :  15617
# Fetched total data :  15714
# Fetched total data :  15811
# Fetched total data :  15908
# Fetched total data :  16005
# Fetched total data :  16102
# Fetched total data :  16199
# Fetched total data :  16296
# Fetched total data :  16393
# Fetched total data :  16490
# Fetched total data :  16587
# Fetched total data :  16684
# Fetched total data :  16781
# Fetched total data :  16878
# Fetched total data :  16975
# Fetched total data :  17072
# Fetched total data :  17169
# Fetched total data :  17266
# Fetched total data :  17363
# Fetched total data :  17460
# Fetched total data :  17557
# Fetched total data :  17654
# Fetched total data :  17751
# Fetched total data :  17848
# Fetched total data :  17945
# Fetched total data :  18042
# Fetched total data :  18139
# Fetched total data :  18236
# Fetched total data :  18333
# Fetched total data :  18430
# Fetched total data :  18527
# Fetched total data :  18624
# Fetched total data :  18721
# Fetched total data :  18818
# Fetched total data :  18915
# Fetched total data :  19012
# Fetched total data :  19109
# Fetched total data :  19206
# Fetched total data :  19303
# Fetched total data :  19400
# Fetched total data :  19497
# Fetched total data :  19594
# Fetched total data :  19691
# Fetched total data :  19788
# Fetched total data :  19885
# Fetched total data :  19982
# Fetched total data :  20079
# Fetched total data :  20176
# Fetched total data :  20273
# Fetched total data :  20370
# Fetched total data :  20467
# Fetched total data :  20564
# Fetched total data :  20661
# Fetched total data :  20758
# Fetched total data :  20855
# Fetched total data :  20952
# Fetched total data :  21049
# Fetched total data :  21146
# Fetched total data :  21243
# Fetched total data :  21340
# Fetched total data :  21437
# Fetched total data :  21534
# Fetched total data :  21631
# Fetched total data :  21728
# Fetched total data :  21825
# Fetched total data :  21922
# Fetched total data :  22019
# Fetched total data :  22116
# Fetched total data :  22213
# Fetched total data :  22310
# Fetched total data :  22407
# Fetched total data :  22504
# Fetched total data :  22601
# Fetched total data :  22698
# Fetched total data :  22795
# Fetched total data :  22892
# Fetched total data :  22989
# Fetched total data :  23086
# Fetched total data :  23183
# Fetched total data :  23280
# Fetched total data :  23377
# Fetched total data :  23474
# Fetched total data :  23571
# Fetched total data :  23668
# Fetched total data :  23765
# Fetched total data :  23862
# Fetched total data :  23959
# Fetched total data :  24056
# Fetched total data :  24153
# Fetched total data :  24250
# Fetched total data :  24347
# Fetched total data :  24444
# Fetched total data :  24541
# Fetched total data :  24638
# Fetched total data :  24735
# Fetched total data :  24832
# Fetched total data :  24929
# Fetched total data :  25026
# Fetched total data :  25123
# Fetched total data :  25220
# Fetched total data :  25317
# Fetched total data :  25414
# Fetched total data :  25511
# Fetched total data :  25608
# Fetched total data :  25705
# Fetched total data :  25802
# Fetched total data :  25899
# Fetched total data :  25996
# Fetched total data :  26093
# Fetched total data :  26190
# Fetched total data :  26287
# Fetched total data :  26384
# Fetched total data :  26481
# Fetched total data :  26578
# Fetched total data :  26675
# Fetched total data :  26772
# Fetched total data :  26869
# Fetched total data :  26966
# Fetched total data :  27063
# Fetched total data :  27160
# Fetched total data :  27257
# Fetched total data :  27354
# Fetched total data :  27451
# Fetched total data :  27548
# Fetched total data :  27645
# Fetched total data :  27742
# Fetched total data :  27839
# Fetched total data :  27936
# Fetched total data :  28033
# Fetched total data :  28130
# Fetched total data :  28227
# Fetched total data :  28324
# Fetched total data :  28421
# Fetched total data :  28518
# Fetched total data :  28615
# Fetched total data :  28712
# Fetched total data :  28809
# Fetched total data :  28906
# Fetched total data :  29003
# Fetched total data :  29100
# Fetched total data :  29197
# Fetched total data :  29294
# Fetched total data :  29391
# Fetched total data :  29488
# Fetched total data :  29585
# Fetched total data :  29682
# Fetched total data :  29779
# Fetched total data :  29876
# Fetched total data :  29973
# Fetched total data :  30070
# Fetched total data :  30167
# Fetched total data :  30264
# Fetched total data :  30361
# Fetched total data :  30458
# Fetched total data :  30555
# Fetched total data :  30652
# Fetched total data :  30749
# Fetched total data :  30846
# Fetched total data :  30943
# Fetched total data :  31040
# Fetched total data :  31137
# Fetched total data :  31234
# Fetched total data :  31331
# Fetched total data :  31428
# Fetched total data :  31525
# Fetched total data :  31622
# Fetched total data :  31719
# Fetched total data :  31816
# Fetched total data :  31913
# Fetched total data :  32010
# Fetched total data :  32107
# Fetched total data :  32204
# Fetched total data :  32301
# Fetched total data :  32398
# Fetched total data :  32495
# Fetched total data :  32592
# Fetched total data :  32689
# Fetched total data :  32786
# Fetched total data :  32883
# Fetched total data :  32980
# Fetched total data :  33077
# Fetched total data :  33174
# Fetched total data :  33271
# Fetched total data :  33368
# Fetched total data :  33465
# Fetched total data :  33562
# Fetched total data :  33659
# Fetched total data :  33756
# Fetched total data :  33853
# Fetched total data :  33950
# Fetched total data :  34047
# Fetched total data :  34144
# Fetched total data :  34241
# Fetched total data :  34338
# Fetched total data :  34435
# Fetched total data :  34532
# Fetched total data :  34629
# Fetched total data :  34726
# Fetched total data :  34823
# Fetched total data :  34920
# Fetched total data :  35017
# Fetched total data :  35114
# Fetched total data :  35211
# Fetched total data :  35308
# Fetched total data :  35405
# Fetched total data :  35502
# Fetched total data :  35599
# Fetched total data :  35696
# Fetched total data :  35793
# Fetched total data :  35890
# Fetched total data :  35987
# Fetched total data :  36084
# Fetched total data :  36181
# Fetched total data :  36278
# Fetched total data :  36375
# Fetched total data :  36472
# Fetched total data :  36569
# Fetched total data :  36666
# Fetched total data :  36763
# Fetched total data :  36860
# Fetched total data :  36957
# Fetched total data :  37054
# Fetched total data :  37151
# Fetched total data :  37248
# Fetched total data :  37345
# Fetched total data :  37442
# Fetched total data :  37539
# Fetched total data :  37636
# Fetched total data :  37733
# Fetched total data :  37830
# Fetched total data :  37927
# Fetched total data :  38024
# Fetched total data :  38121
# Fetched total data :  38218
# Fetched total data :  38315
# Fetched total data :  38412
# Fetched total data :  38509
# Fetched total data :  38606
# Fetched total data :  38703
# Fetched total data :  38800
# Fetched total data :  38897
# Fetched total data :  38994
# Fetched total data :  39091
# Fetched total data :  39188
# Fetched total data :  39285
# Fetched total data :  39382
# Fetched total data :  39479
# Fetched total data :  39576
# Fetched total data :  39673
# Fetched total data :  39770
# Fetched total data :  39867
# Fetched total data :  39964
# Fetched total data :  40061
# Fetched total data :  40158
# Fetched total data :  40255
# Fetched total data :  40352
# Fetched total data :  40449
# Fetched total data :  40546
# Fetched total data :  40643
# Fetched total data :  40740
# Fetched total data :  40837
# Fetched total data :  40934
# Fetched total data :  41031
# Fetched total data :  41128
# Fetched total data :  41225
# Fetched total data :  41322
# Fetched total data :  41419
# Fetched total data :  41516
# Fetched total data :  41613
# Fetched total data :  41710
# Fetched total data :  41807
# Fetched total data :  41904
# Fetched total data :  42001
# Fetched total data :  42098
# Fetched total data :  42195
# Fetched total data :  42292
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 65
#      62     print("Fetched total data : ",len(all_articles_df))
#      64     # Pause to respect API rate limits
# ---> 65     time.sleep(1)
#      67 # Check if we have reached the required number of articles
#      68 if len(all_articles_df) >= article_count:
#
# KeyboardInterrupt:
