# %%
import requests
import json

# Define the URL and API key
url = "https://api.deepgram.com/v1/listen?model=nova-2&smart_format=true"
api_key = "b7abf9d8190a25b5f93ca15ff8f5d048df0987bd"

# Define the headers
headers = {
    "Authorization": f"Token {api_key}",
    "Content-Type": "application/json"
}

# Define the payload
data = {
    "url": "https://static.deepgram.com/examples/interview_speech-analytics.wav"
}

# Make the POST request
response = requests.post(url, headers=headers, data=json.dumps(data))

# Print the response
print(response.status_code)
print(response.json())
# Out:
# 200
# {'metadata': {'transaction_key': 'deprecated', 'request_id': 'fa2cc6cc-6838-4f42-823f-87ede50caa2d', 'sha256': '6a7d98db8babaf70429d80e33b2dc81bc34ebd24bf3a141065ec6883ec696a88', 'created': '2024-06-22T15:17:45.878Z', 'duration': 96.56319, 'channels': 1, 'models': ['30089e05-99d1-4376-b32e-c263170674af'], 'model_info': {'30089e05-99d1-4376-b32e-c263170674af': {'name': '2-general-nova', 'version': '2024-01-09.29447', 'arch': 'nova-2'}}}, 'results': {'channels': [{'alternatives': [{'transcript': "Another big problem in the speech analytics space, when customers first bring the software on is that they they are blown away by the fact that an engine can monitor 100 of KPIs. Right? Everything from minute compliance issues to, you know, human, human interaction, empathy measurements, to upsell, aptitudes, to closing aptitudes. There are 100, literally, of KPIs that one could look at. And the speech analytics companies have typically gone to the customer and really bang that drum. Look at all of these things that we're gonna help you keep an eye on. The reality, however, is that a company even a contact center manager, they can't keep track in their brain, even if they have a report in front of them, of that many KPIs. Mhmm. And, frankly, it's overwhelming. So what successful companies do is they bite off no more than they can chew at any given time. The reality is is you can only train a call center agent on a maximum of 3 skills at any given day. Right? And by focusing on, focusing on problem areas for a week, for a month, depending on how bad things are, and then once you've mastered that skill, to take a baseline of of your performance and move on to the next worst skill, right, is the way that companies succeed using this product.", 'confidence': 0.999156, 'words': [{'word': 'another', 'start': 0.24, 'end': 0.74, 'confidence': 0.99864024, 'punctuated_word': 'Another'}, {'word': 'big', 'start': 0.84, 'end': 1.3399999, 'confidence': 0.9996836, 'punctuated_word': 'big'}, {'word': 'problem', 'start': 1.4399999, 'end': 1.9399999, 'confidence': 0.9998523, 'punctuated_word': 'problem'}, {'word': 'in', 'start': 2.08, 'end': 2.32, 'confidence': 0.9987663, 'punctuated_word': 'in'}, {'word': 'the', 'start': 2.32, 'end': 2.48, 'confidence': 0.99850214, 'punctuated_word': 'the'}, {'word': 'speech', 'start': 2.48, 'end': 2.8, 'confidence': 0.9991386, 'punctuated_word': 'speech'}, {'word': 'analytics', 'start': 2.8, 'end': 3.3, 'confidence': 0.8336932, 'punctuated_word': 'analytics'}, {'word': 'space', 'start': 3.36, 'end': 3.86, 'confidence': 0.9966767, 'punctuated_word': 'space,'}, {'word': 'when', 'start': 4.48, 'end': 4.7999997, 'confidence': 0.99987197, 'punctuated_word': 'when'}, {'word': 'customers', 'start': 4.7999997, 'end': 5.2999997, 'confidence': 0.99948823, 'punctuated_word': 'customers'}, {'word': 'first', 'start': 5.3599997, 'end': 5.6, 'confidence': 0.97918874, 'punctuated_word': 'first'}, {'word': 'bring', 'start': 5.6, 'end': 5.8399997, 'confidence': 0.9998399, 'punctuated_word': 'bring'}, {'word': 'the', 'start': 5.8399997, 'end': 6.0, 'confidence': 0.98880976, 'punctuated_word': 'the'}, {'word': 'software', 'start': 6.0, 'end': 6.48, 'confidence': 0.9999081, 'punctuated_word': 'software'}, {'word': 'on', 'start': 6.48, 'end': 6.96, 'confidence': 0.999542, 'punctuated_word': 'on'}, {'word': 'is', 'start': 6.96, 'end': 7.12, 'confidence': 0.83591986, 'punctuated_word': 'is'}, {'word': 'that', 'start': 7.12, 'end': 7.52, 'confidence': 0.99968445, 'punctuated_word': 'that'}, {'word': 'they', 'start': 7.52, 'end': 8.02, 'confidence': 0.993028, 'punctuated_word': 'they'}, {'word': 'they', 'start': 8.724999, 'end': 9.125, 'confidence': 0.9999131, 'punctuated_word': 'they'}, {'word': 'are', 'start': 9.125, 'end': 9.625, 'confidence': 0.9997131, 'punctuated_word': 'are'}, {'word': 'blown', 'start': 9.844999, 'end': 10.245, 'confidence': 0.9997708, 'punctuated_word': 'blown'}, {'word': 'away', 'start': 10.245, 'end': 10.485, 'confide ...

# %%
pip install requests pydub simpleaudio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in c:\users\umesh\appdata\roaming\python\python311\site-packages (2.32.3)
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting simpleaudio
#   Downloading simpleaudio-1.0.4.tar.gz (2.0 MB)
#      ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/2.0 MB 162.5 kB/s eta 0:00:13
#      - -------------------------------------- 0.1/2.0 MB 327.7 kB/s eta 0:00:07
#      ---- ----------------------------------- 0.2/2.0 MB 1.4 MB/s eta 0:00:02
#      --------- ------------------------------ 0.5/2.0 MB 2.1 MB/s eta 0:00:01
#      ------------ --------------------------- 0.6/2.0 MB 2.4 MB/s eta 0:00:01
#      -------------- ------------------------- 0.7/2.0 MB 2.4 MB/s eta 0:00:01
#      ------------------ --------------------- 1.0/2.0 MB 2.7 MB/s eta 0:00:01
#      ----------------------- ---------------- 1.2/2.0 MB 2.9 MB/s eta 0:00:01
#      --------------------------- ------------ 1.4/2.0 MB 3.1 MB/s eta 0:00:01
#      -------------------------------- ------- 1.7/2.0 MB 3.3 MB/s eta 0:00:01
#      -------------------------------------- - 1.9/2.0 MB 3.5 MB/s eta 0:00:01
#      ---------------------------------------  2.0/2.0 MB 3.6 MB/s eta 0:00:01
#      ---------------------------------------- 2.0/2.0 MB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\umesh\appdata\roaming\python\python311\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\umesh\appdata\roaming\python\python311\site-packages (from requests) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\umesh\appdata\roaming\python\python311\site-packages (from requests) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\umesh\appdata\roaming\python\python311\site-packages (from requests) (2024.2.2)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Building wheels for collected packages: simpleaudio
#   Building wheel for simpleaudio (setup.py): started
#   Building wheel for simpleaudio (setup.py): finished with status 'done'
#   Created wheel for simpleaudio: filename=simpleaudio-1.0.4-cp311-cp311-win_amd64.whl size=2039093 sha256=2fbba6a81e3515442dc7c5713e9d282d6015d16bb078aa482f077b13caf79ab2
#   Stored in directory: c:\users\umesh\appdata\local\pip\cache\wheels\44\74\11\9d2cf6ddf5d0dcc7750484a371b92fdb036f5496d1d4b42d08
# Successfully built simpleaudio
# Installing collected packages: simpleaudio, pydub
# Successfully installed pydub-0.25.1 simpleaudio-1.0.4
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pygame
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pygame
#   Downloading pygame-2.5.2-cp311-cp311-win_amd64.whl.metadata (13 kB)
# Downloading pygame-2.5.2-cp311-cp311-win_amd64.whl (10.8 MB)
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------------------------------------- 0.1/10.8 MB 1.7 MB/s eta 0:00:07
#    - -------------------------------------- 0.5/10.8 MB 4.7 MB/s eta 0:00:03
#    -- ------------------------------------- 0.8/10.8 MB 6.1 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.1/10.8 MB 6.4 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.4/10.8 MB 5.9 MB/s eta 0:00:02
#    ------ --------------------------------- 1.8/10.8 MB 6.5 MB/s eta 0:00:02
#    ------- -------------------------------- 2.0/10.8 MB 6.7 MB/s eta 0:00:02
#    ------- -------------------------------- 2.1/10.8 MB 5.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.2/10.8 MB 6.0 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.8/10.8 MB 6.0 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.2/10.8 MB 6.6 MB/s eta 0:00:02
#    -------------- ------------------------- 3.9/10.8 MB 7.1 MB/s eta 0:00:01
#    --------------- ------------------------ 4.2/10.8 MB 7.1 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.6/10.8 MB 7.1 MB/s eta 0:00:01
#    ------------------ --------------------- 5.0/10.8 MB 7.2 MB/s eta 0:00:01
#    ------------------- -------------------- 5.2/10.8 MB 7.0 MB/s eta 0:00:01
#    ------------------- -------------------- 5.3/10.8 MB 7.1 MB/s eta 0:00:01
#    --------------------- ------------------ 5.8/10.8 MB 7.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.1/10.8 MB 7.0 MB/s eta 0:00:01
#    ------------------------ --------------- 6.5/10.8 MB 7.0 MB/s eta 0:00:01
#    ------------------------- -------------- 6.7/10.8 MB 6.9 MB/s eta 0:00:01
#    -------------------------- ------------- 7.1/10.8 MB 7.0 MB/s eta 0:00:01
#    --------------------------- ------------ 7.3/10.8 MB 6.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.7/10.8 MB 6.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.9/10.8 MB 6.9 MB/s eta 0:00:01
#    ------------------------------- -------- 8.3/10.8 MB 6.9 MB/s eta 0:00:01
#    -------------------------------- ------- 8.7/10.8 MB 6.9 MB/s eta 0:00:01
#    --------------------------------- ------ 9.1/10.8 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.4/10.8 MB 7.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.6/10.8 MB 6.9 MB/s eta 0:00:01
#    ------------------------------------ --- 9.9/10.8 MB 6.9 MB/s eta 0:00:01
#    ------------------------------------- -- 10.2/10.8 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------  10.6/10.8 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------  10.8/10.8 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 10.8/10.8 MB 6.8 MB/s eta 0:00:00
# Installing collected packages: pygame
# Successfully installed pygame-2.5.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pygame
from deepgram import DeepgramClient, SpeakOptions

# Initialize pygame mixer
pygame.mixer.init()

# Define the Deepgram API key and options
DEEPGRAM_API_KEY = "b7abf9d8190a25b5f93ca15ff8f5d048df0987bd"  # Replace with your actual Deepgram API key
SPEAK_OPTIONS = {"text": "Hello, how can I help you today?"}
filename = "output.mp3"

def main():
    try:
        # STEP 1: Create a Deepgram client.
        # By default, the DEEPGRAM_API_KEY environment variable will be used for the API Key
        deepgram = DeepgramClient(api_key=DEEPGRAM_API_KEY)

        # STEP 2: Configure the options (such as model choice, audio configuration, etc.)
        options = SpeakOptions(
            model="aura-asteria-en",
        )

        # STEP 3: Call the save method on the speak property
        save_to_file(deepgram, filename, SPEAK_OPTIONS, options)
        print(f"File '{filename}' saved successfully.")

        # Play the generated MP3 file using pygame
        play_audio(filename)

    except Exception as e:
        print(f"Exception: {e}")

def save_to_file(deepgram, filename, speak_options, options):
    # Open the file in binary write mode
    with open(filename, "wb") as f:
        # Save the audio content to the file
        response = deepgram.speak.v("1").save(f, speak_options, options)
    
    # Close the file explicitly
    f.close()

def play_audio(filename):
    pygame.mixer.music.load(filename)
    pygame.mixer.music.play()

    # Wait for the audio to finish playing
    while pygame.mixer.music.get_busy():
        pygame.time.Clock().tick(10)

if __name__ == "__main__":
    main()
# Out:
# Exception: [Errno 13] Permission denied: 'output.mp3'

# %%
import os
import pygame
from deepgram import DeepgramClient, SpeakOptions
from datetime import datetime

# Initialize pygame mixer
pygame.mixer.init()

# Define the Deepgram API key and options
DEEPGRAM_API_KEY = "b7abf9d8190a25b5f93ca15ff8f5d048df0987bd"  # Replace with your actual Deepgram API key
SPEAK_OPTIONS = {"text": "Hello, how can I help you today?"}
output_dir = "output_files"  # Directory where output files will be saved

def main():
    try:
        # STEP 1: Create a Deepgram client.
        # By default, the DEEPGRAM_API_KEY environment variable will be used for the API Key
        deepgram = DeepgramClient(api_key=DEEPGRAM_API_KEY)

        # STEP 2: Configure the options (such as model choice, audio configuration, etc.)
        options = SpeakOptions(
            model="aura-asteria-en",
        )

        # Generate a unique filename with timestamp
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        filename = os.path.join(output_dir, f"output_{timestamp}.mp3")

        # STEP 3: Call the save method on the speak property
        save_to_file(deepgram, filename, SPEAK_OPTIONS, options)
        print(f"File '{filename}' saved successfully.")

        # Play the generated MP3 file using pygame
        play_audio(filename)

    except Exception as e:
        print(f"Exception: {e}")

def save_to_file(deepgram, filename, speak_options, options):
    # Ensure output directory exists
    os.makedirs(output_dir, exist_ok=True)

    # Save the audio content to the file
    response = deepgram.speak.v("1").save(filename, speak_options, options)

def play_audio(filename):
    pygame.mixer.music.load(filename)
    pygame.mixer.music.play()

    # Wait for the audio to finish playing
    while pygame.mixer.music.get_busy():
        pygame.time.Clock().tick(10)

if __name__ == "__main__":
    main()
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# File 'output_files\output_20240622_143014.mp3' saved successfully.

# %%
# ??????????

# %%
import os
import pygame
from deepgram import DeepgramClient, SpeakOptions

# Initialize pygame mixer
pygame.mixer.init()

# Define the Deepgram API key and options
DEEPGRAM_API_KEY = "your_deepgram_api_key_here"  # Replace with your actual Deepgram API key
SPEAK_OPTIONS = {"text": ""}  # Placeholder for TTS options

def generate_audio_from_text(text, filename):
    deepgram = DeepgramClient(api_key=DEEPGRAM_API_KEY)
    options = SpeakOptions(
        model="aura-asteria-en",
    )
    response = deepgram.speak.v("1").save(filename, {"text": text}, options)
    return filename

# %%
pip install groq
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting groq
#   Downloading groq-0.9.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\umesh\appdata\roaming\python\python311\site-packages (from groq) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\umesh\appdata\roaming\python\python311\site-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\umesh\appdata\roaming\python\python311\site-packages (from groq) (0.26.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\umesh\appdata\roaming\python\python311\site-packages (from groq) (2.6.1)
# Requirement already satisfied: sniffio in c:\users\umesh\appdata\roaming\python\python311\site-packages (from groq) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\umesh\appdata\roaming\python\python311\site-packages (from groq) (4.9.0)
# Requirement already satisfied: idna>=2.8 in c:\users\umesh\appdata\roaming\python\python311\site-packages (from anyio<5,>=3.5.0->groq) (2.10)
# Requirement already satisfied: certifi in c:\users\umesh\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.23.0->groq) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\umesh\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.23.0->groq) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\umesh\appdata\roaming\python\python311\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\umesh\appdata\roaming\python\python311\site-packages (from pydantic<3,>=1.9.0->groq) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in c:\users\umesh\appdata\roaming\python\python311\site-packages (from pydantic<3,>=1.9.0->groq) (2.16.2)
# Downloading groq-0.9.0-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.5 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/103.5 kB ? eta -:--:--
#    ---------------------------------------- 103.5/103.5 kB 2.0 MB/s eta 0:00:00
# Installing collected packages: groq
# Successfully installed groq-0.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from groq import Groq

# Initialize Groq client
groq_client = Groq(api_key="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")  # Replace with your actual Groq API key

def get_groq_response(user_input, conversation_history):
    # Add user input to conversation history
    conversation_history.append({
        "role": "user",
        "content": user_input
    })

    # Generate response from the model
    chat_completion = groq_client.chat.completions.create(
        messages=conversation_history,
        model="llama3-8b-8192"
    )

    ai_response = chat_completion.choices[0].message.content

    # Add AI response to conversation history
    conversation_history.append({
        "role": "assistant",
        "content": ai_response
    })

    return ai_response, conversation_history

# %%
import os
import pygame
from deepgram import DeepgramClient, SpeakOptions

# Initialize pygame mixer
pygame.mixer.init()

# Define the Deepgram API key and options
DEEPGRAM_API_KEY = "b7abf9d8190a25b5f93ca15ff8f5d048df0987bd"  # Replace with your actual Deepgram API key
SPEAK_OPTIONS = {"text": "Hello, how can I help you today?"}
filename = "output.mp3"

# Initialize Groq client
client = Groq(api_key="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")

# Initial system message setting the context
conversation_history = [
    {
        "role": "system",
        "content": "You are a receptionist at a Heating and Ventilation and Air Conditioning Company. Be resourceful and efficient. Your Company sells Heat Pumps and Air Conditioners. The available sales agents are Raju and Sanat. Only answer in two sentences."
    }
]

# Initialize Groq client
groq_client = Groq(api_key="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")  # Replace with your actual Groq API key

def get_groq_response(user_input, conversation_history):
    # Add user input to conversation history
    conversation_history.append({
        "role": "user",
        "content": user_input
    })

    # Generate response from the model
    chat_completion = groq_client.chat.completions.create(
        messages=conversation_history,
        model="llama3-8b-8192"
    )

    ai_response = chat_completion.choices[0].message.content

    # Add AI response to conversation history
    conversation_history.append({
        "role": "assistant",
        "content": ai_response
    })

    return ai_response, conversation_history

def main():
    try:
        # STEP 1: Create a Deepgram client.
        # By default, the DEEPGRAM_API_KEY environment variable will be used for the API Key
        deepgram = DeepgramClient(api_key=DEEPGRAM_API_KEY)

        # STEP 2: Configure the options (such as model choice, audio configuration, etc.)
        options = SpeakOptions(
            model="aura-asteria-en",
        )

        while True:
            user_input = input("User: ")
    
            # Get Groq response
            ai_response, conversation_history = get_groq_response(user_input, conversation_history)
            print("AI:", ai_response)
    
            # Generate a unique filename with timestamp
            timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
            filename = os.path.join(output_dir, f"output_{timestamp}.mp3")
    
            # Play the generated audio using pygame
            play_audio(audio_filename)
    
            # STEP 3: Call the save method on the speak property
            save_to_file(deepgram, filename, ai_response, options)
            print(f"File '{filename}' saved successfully.")
    
            # Play the generated MP3 file using pygame
            play_audio(filename)
    
            # Exit condition (example)
            if user_input.lower() == "exit":
                break

        
    except Exception as e:
        print(f"Exception: {e}")

def save_to_file(deepgram, filename, speak_options, options):
    # Open the file in binary write mode
    with open(filename, "wb") as f:
        # Save the audio content to the file
        response = deepgram.speak.v("1").save(f, speak_options, options)
    
    # Close the file explicitly
    f.close()

def play_audio(filename):
    pygame.mixer.music.load(filename)
    pygame.mixer.music.play()

    # Wait for the audio to finish playing
    while pygame.mixer.music.get_busy():
        pygame.time.Clock().tick(10)

if __name__ == "__main__":
    main()
# Out:
# User:  Hello i need help with pump
# Exception: cannot access local variable 'conversation_history' where it is not associated with a value

# %%
import os
import pygame
from datetime import datetime
from deepgram import DeepgramClient, SpeakOptions
from groq import Groq

# Initialize pygame mixer
pygame.mixer.init()

# Define the Deepgram API key and options
DEEPGRAM_API_KEY = "b7abf9d8190a25b5f93ca15ff8f5d048df0987bd"  # Replace with your actual Deepgram API key
output_dir = "data"  # Directory to save audio files

# Ensure output directory exists
os.makedirs(output_dir, exist_ok=True)

# Initialize Groq client
groq_client = Groq(api_key="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")  # Replace with your actual Groq API key

def get_groq_response(user_input, conversation_history):
    # Add user input to conversation history
    conversation_history.append({
        "role": "user",
        "content": user_input
    })

    # Generate response from the model
    chat_completion = groq_client.chat.completions.create(
        messages=conversation_history,
        model="llama3-8b-8192"
    )

    ai_response = chat_completion.choices[0].message.content

    # Add AI response to conversation history
    conversation_history.append({
        "role": "assistant",
        "content": ai_response
    })

    return ai_response, conversation_history

def main():
    try:
        # STEP 1: Create a Deepgram client.
        # By default, the DEEPGRAM_API_KEY environment variable will be used for the API Key
        deepgram = DeepgramClient(api_key=DEEPGRAM_API_KEY)

        while True:
            user_input = input("User: ")

            # Initialize or retrieve conversation history
            conversation_history = initialize_or_load_history()

            # Get Groq response
            ai_response, updated_history = get_groq_response(user_input, conversation_history)
            print("AI:", ai_response)

            # Update conversation history
            save_history(updated_history)

            # Generate a unique filename with timestamp
            timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
            filename = os.path.join(output_dir, f"output_{timestamp}.mp3")

            # STEP 2: Configure the options (such as model choice, audio configuration, etc.)
            options = SpeakOptions(
                model="aura-asteria-en",
            )

            # STEP 3: Call the save method on the speak property
            save_to_file(deepgram, filename, ai_response, options)
            print(f"File '{filename}' saved successfully.")

            # Play the generated MP3 file using pygame
            play_audio(filename)

            # Exit condition (example)
            if user_input.lower() == "exit":
                break

    except Exception as e:
        print(f"Exception: {e}")

def initialize_or_load_history():
    # Load or initialize conversation history
    if os.path.exists("conversation_history.txt"):
        with open("conversation_history.txt", "r") as file:
            conversation_history = eval(file.read())
    else:
        conversation_history = [
            {
                "role": "system",
                "content": "You are a receptionist at a Heating and Ventilation and Air Conditioning Company. Be resourceful and efficient. Your Company sells Heat Pumps and Air Conditioners. The available sales agents are Raju and Sanat. Only answer in two sentences."
            }
        ]
        save_history(conversation_history)

    return conversation_history

def save_history(conversation_history):
    # Save conversation history to file
    with open("conversation_history.txt", "w") as file:
        file.write(repr(conversation_history))

def save_to_file(deepgram, filename, ai_response, options):
    # Open the file in binary write mode
    with open(filename, "wb") as f:
        # Save the audio content to the file
        deepgram.speak.v("1").save(f, {"text": ai_response}, options)

def play_audio(filename):
    pygame.mixer.music.load(filename)
    pygame.mixer.music.play()

    # Wait for the audio to finish playing
    while pygame.mixer.music.get_busy():
        pygame.time.Clock().tick(10)

if __name__ == "__main__":
    main()
# Out:
# User:  Hello
# AI: Welcome to HVAC Solutions! Can I assist you with a quote or inquiry for a heat pump or air conditioner, and which sales agent would you like to work with, Raju or Sanat?
# Exception: expected str, bytes or os.PathLike object, not BufferedWriter

# %%
import os
import pygame
from deepgram import DeepgramClient, SpeakOptions
from groq import Groq
from datetime import datetime

# Initialize pygame mixer
pygame.mixer.init()

# Define API keys and options
DEEPGRAM_API_KEY = "b7abf9d8190a25b5f93ca15ff8f5d048df0987bd"  # Replace with your actual Deepgram API key
GROQ_API_KEY = "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"  # Replace with your actual Groq API key
output_dir = "audio_output"  # Directory to save audio files

# Ensure output directory exists
os.makedirs(output_dir, exist_ok=True)

# Initialize Deepgram client
deepgram = DeepgramClient(api_key=DEEPGRAM_API_KEY)

# Initialize Groq client
groq_client = Groq(api_key=GROQ_API_KEY)

def get_groq_response(user_input, conversation_history):
    # Add user input to conversation history
    conversation_history.append({
        "role": "user",
        "content": user_input
    })

    # Generate response from the model
    chat_completion = groq_client.chat.completions.create(
        messages=conversation_history,
        model="llama3-8b-8192"
    )

    ai_response = chat_completion.choices[0].message.content

    # Add AI response to conversation history
    conversation_history.append({
        "role": "assistant",
        "content": ai_response
    })

    return ai_response, conversation_history

def save_to_file(filename, text):
    # Generate unique filename with timestamp
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    filename = os.path.join(output_dir, f"{filename}_{timestamp}.mp3")

    # Configure Deepgram options
    options = SpeakOptions(model="aura-asteria-en")

    # Open the file in binary write mode
    with open(filename, "wb") as f:
        # Save the audio content to the file
        deepgram.speak.v("1").save(f, {"text": text}, options)

    return filename

def play_audio(filename):
    pygame.mixer.music.load(filename)
    pygame.mixer.music.play()

    # Wait for the audio to finish playing
    while pygame.mixer.music.get_busy():
        pygame.time.Clock().tick(10)

def main():
    try:
        # Initial system message setting the context
        conversation_history = [
            {
                "role": "system",
                "content": "You are a receptionist at a Heating and Ventilation and Air Conditioning Company. Be resourceful and efficient. Your Company sells Heat Pumps and Air Conditioners. The available sales agents are Raju and Sanat. Only answer in two sentences."
            }
        ]

        while True:
            user_input = input("User: ")

            # Get Groq response
            ai_response, conversation_history = get_groq_response(user_input, conversation_history)
            print("AI:", ai_response)

            # Save AI response to file
            filename = save_to_file("output", ai_response)
            print(f"File '{filename}' saved successfully.")

            # Play the saved audio file using pygame
            play_audio(filename)

            # Exit condition example
            if user_input.lower() == "exit":
                break

    except Exception as e:
        print(f"Exception: {e}")

if __name__ == "__main__":
    main()
# Out:
# User:  Hello. I need help with pump
# AI: I'd be happy to assist you with your Heat Pump or Air Conditioner needs. Can you please specify what type of issue you're experiencing or what you're looking for - a repair, maintenance, or a new installation?
# Exception: expected str, bytes or os.PathLike object, not BufferedWriter

# %%
import os
import pygame
from deepgram import DeepgramClient, SpeakOptions
from groq import Groq
from datetime import datetime

# Initialize pygame mixer
pygame.mixer.init()

# Define API keys and options
DEEPGRAM_API_KEY = "b7abf9d8190a25b5f93ca15ff8f5d048df0987bd"  # Replace with your actual Deepgram API key
GROQ_API_KEY = "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"  # Replace with your actual Groq API key
output_dir = "audio_output"  # Directory to save audio files

# Ensure output directory exists
os.makedirs(output_dir, exist_ok=True)

# Initialize Deepgram client
deepgram = DeepgramClient(api_key=DEEPGRAM_API_KEY)

# Initialize Groq client
groq_client = Groq(api_key=GROQ_API_KEY)

def get_groq_response(user_input, conversation_history):
    # Add user input to conversation history
    conversation_history.append({
        "role": "user",
        "content": user_input
    })

    # Generate response from the model
    chat_completion = groq_client.chat.completions.create(
        messages=conversation_history,
        model="llama3-8b-8192"
    )

    ai_response = chat_completion.choices[0].message.content

    # Add AI response to conversation history
    conversation_history.append({
        "role": "assistant",
        "content": ai_response
    })

    return ai_response, conversation_history

def save_to_file(filename, text):
    # Generate unique filename with timestamp
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    filename = os.path.join(output_dir, f"{filename}_{timestamp}.mp3")

    # Configure Deepgram options
    options = SpeakOptions(model="aura-asteria-en")

    # Save the audio content to the file
    response = deepgram.speak.v("1").save(filename, {"text": text}, options)

    return filename

def play_audio(filename):
    pygame.mixer.music.load(filename)
    pygame.mixer.music.play()

    # Wait for the audio to finish playing
    while pygame.mixer.music.get_busy():
        pygame.time.Clock().tick(10)

def main():
    try:
        # Initial system message setting the context
        conversation_history = [
            {
                "role": "system",
                "content": "You are a receptionist at a Heating and Ventilation and Air Conditioning Company. Be resourceful and efficient. Your Company sells Heat Pumps and Air Conditioners. The available sales agents are Raju and Sanat. Only answer in two sentences."
            }
        ]

        while True:
            user_input = input("User: ")

            # Get Groq response
            ai_response, conversation_history = get_groq_response(user_input, conversation_history)
            print("AI:", ai_response)

            # Save AI response to file
            filename = save_to_file("output", ai_response)
            print(f"File '{filename}' saved successfully.")

            # Play the saved audio file using pygame
            play_audio(filename)

            # Exit condition example
            if user_input.lower() == "exit":
                break

    except Exception as e:
        print(f"Exception: {e}")

if __name__ == "__main__":
    main()
# Out:
# User:  Hello
# AI: Welcome to our Heating and Ventilation and Air Conditioning Company! Perhaps I can assist you with your cooling or heating needs, or match you with one of our knowledgeable sales agents, Raju or Sanat?
# File 'audio_output\output_20240622_144944.mp3' saved successfully.
# User:  Sanat please
# AI: I'll get Sanat on the line to help you with your heat pump or air conditioner needs. Can you please hold for just a moment while I transfer the call?
# File 'audio_output\output_20240622_145004.mp3' saved successfully.
# User:  Sure
# AI: Sanat is on the line and ready to help you. Good afternoon, Sanat speaking, how can I assist you with your HVAC needs today?
# File 'audio_output\output_20240622_145017.mp3' saved successfully.
# User:  i want to install hvac on my home
# AI: We'd be happy to help you with that! Sanat will guide you through our selection of top-notch heat pumps and air conditioners, and help you choose the perfect system for your home's unique needs.
# File 'audio_output\output_20240622_145104.mp3' saved successfully.
# User:  i am in Toronto
# AI: Toronto has a specific climate, so we'll make sure to take that into consideration when selecting a system that suits your needs.
# File 'audio_output\output_20240622_145125.mp3' saved successfully.
# User:  What service should i take
# AI: Based on Toronto's climate, I'd recommend considering our high-efficiency heat pump or air conditioner systems, and Sanat can help you decide which one would be best for your home, considering factors like insulation, windows, and occupancy.
# File 'audio_output\output_20240622_164015.mp3' saved successfully.
